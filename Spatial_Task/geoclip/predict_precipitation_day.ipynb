# %%
import sys
# sys.path.append('./satclip')
import matplotlib.pyplot as plt
import torch
# from load import get_satclip
from mpl_toolkits.basemap import Basemap
from urllib import request
import numpy as np
import pandas as pd
import io
import torch
from torch.utils.data import TensorDataset, random_split


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu') # Automatically select device
import torch.nn as nn

class MLP(nn.Module):
    def __init__(self, input_dim, dim_hidden, num_layers, out_dims):
        super(MLP, self).__init__()

        layers = []
        layers += [nn.Linear(input_dim, dim_hidden, bias=True), nn.ReLU()] # Input layer
        layers += [nn.Linear(dim_hidden, dim_hidden, bias=True), nn.ReLU()] * num_layers # Hidden layers
        layers += [nn.Linear(dim_hidden, out_dims, bias=True)] # Output layer

        self.features = nn.Sequential(*layers)

    def forward(self, x):
        return self.features(x)

def convert_to_lat_lon(data):
    """
    Converts a list of numbers between 0 and 64799 to a list of latitudes and longitudes within the range [-89, 90] and [-180, 179].

    Args:
        data (list): A list of numbers between 0 and 64799.

    Returns:
        list: A list of tuples representing latitudes and longitudes.
    """

    latitudes = []
    longitudes = []

    for number in data:
        # Convert number to latitude and longitude coordinates
        latitude = (number // 360) - 89
        longitude = (number % 360) - 180

        # Append coordinates to lists
        latitudes.append(latitude)
        longitudes.append(longitude)

    return list(zip(latitudes, longitudes))

def calculate_lat_lon(row):
    # 这里是你的函数，我假设它是func
    # import ipdb; ipdb.set_trace()
    lat, lon = convert_to_lat_lon([row.name])[0]
    lat = lat + 0.5
    lon = lon + 0.5
    return pd.Series({'lat': lat, 'lon': lon})

def get_air_temp_data(pred="temp",
                      norm_y=True,
                      norm_x=True
                      ):
    '''
    Download and process the Global Air Temperature dataset (more info: https://www.nature.com/articles/sdata2018246)

    Parameters:
    pred = numeric; outcome variable to be returned; choose from ["temp", "prec"]
    norm_y = logical; should outcome be normalized
    norm_min_val = integer; choice of [0,1], setting whether normalization in range[0,1] or [-1,1]

    Return:
    coords = spatial coordinates (lon/lat)
    x = features at location
    y = outcome variable
    '''
    #   url = 'https://springernature.figshare.com/ndownloader/files/12609182'
    #   url_open = request.urlopen(url)
    
    # inc = np.array(pd.read_csv(io.StringIO(url_open.read().decode('utf-8'))))
    inc = pd.read_csv('../data/precipitation_avg_day.csv',names=['precipitation_value'])
    # 定义函数来计算经纬度

    # 计算经纬度并添加到DataFrame
    inc[['lat', 'lon']] = inc.apply(calculate_lat_lon, axis=1)
    inc = np.array(inc)
    y = inc[:,0].reshape(-1)
    coords = inc[:,1:]
    # import ipdb; ipdb.set_trace()
    # coords = coords[:,::-1]
    y_mean = np.mean(y)
    y_std = np.std(y)
    y = (y - y_mean) / y_std

    return torch.tensor(coords.copy()),  torch.tensor(y), y_mean, y_std



#先lat，再lon
coords, y, y_mean, y_std = get_air_temp_data()
# print(coords)
# import matplotlib.pyplot as plt
# from mpl_toolkits.basemap import Basemap

fig, ax = plt.subplots(1, figsize=(5, 3))

m = Basemap(projection='cyl', resolution='c', ax=ax)
m.drawcoastlines()
scatter = ax.scatter(coords[:,1], coords[:,0], c=y, s=5)
ax.set_title('Precipitation')

# 添加colorbar
cbar = plt.colorbar(scatter)
# cbar.set_label('wind')

plt.show()

# %%
# import torch
from geoclip import LocationEncoder

model = LocationEncoder()
model.load_state_dict(
        torch.load('location_encoder_weights.pth')
)
model.to(device)
model.eval()
# import ipdb; ipdb.set_trace()
# print(coords.dtype)
# coords = coords.double()
with torch.no_grad():
  # x  = model(coords.double().to(device)).detach().cpu()
  # x  = model(coords.to(device)).detach().cpu()
  x  = model(coords.float().to(device)).detach().cpu()

print(coords.shape)
print(x.shape)


dataset = TensorDataset(coords, x, y)

# train_size = int(0.8 * len(dataset))
train_size = int(0.7 * len(dataset))
test_size = len(dataset) - train_size
train_set, test_set = random_split(dataset, [train_size, test_size])

coords_train, x_train, y_train = train_set.dataset.tensors[0][train_set.indices], train_set.dataset.tensors[1][train_set.indices], train_set.dataset.tensors[2][train_set.indices]
coords_test, x_test, y_test = test_set.dataset.tensors[0][test_set.indices], test_set.dataset.tensors[1][test_set.indices], test_set.dataset.tensors[2][test_set.indices]

fig, ax = plt.subplots(1, figsize=(5, 3))

m = Basemap(projection='cyl', resolution='c', ax=ax)
m.drawcoastlines()
ax.scatter(coords_train[:,1], coords_train[:,0], c='blue', s=2, label='Training',alpha=0.5)
ax.scatter(coords_test[:,1], coords_test[:,0], c='green', s=2, label='Testing',alpha=0.5)
ax.legend()
ax.set_title('Train-Test Split')
# Out:
# torch.Size([64800, 2])
# torch.Size([64800, 512])
# Text(0.5, 1.0, 'Train-Test Split')

# %%
# plt.savefig('pra.jpg')
# import ipdb; ipdb.set_trace()
pred_model = MLP(input_dim=512, dim_hidden=64, num_layers=2, out_dims=1).float().to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(pred_model.parameters(), lr=0.001)

losses = []
epochs = 100000
patience = 100  # Number of epochs with no improvement after which training will be stopped
early_stop_counter = 0  # Counter for early stopping
best_loss = None  # Best loss value

# import ipdb; ipdb.set_trace()
for epoch in range(epochs):
    optimizer.zero_grad()
    # Forward pass
    y_pred = pred_model(x_train.float().to(device))
    # Compute the loss
    loss = criterion(y_pred.reshape(-1), y_train.float().to(device))
    # Backward pass
    loss.backward()
    # Update the parameters
    optimizer.step()
    # Append the loss to the list
    losses.append(loss.item())
    if (epoch + 1) % 250 == 0:
        print(f"Epoch {epoch + 1}, MSE Loss: {loss.item():.4f}")
        print(f"Epoch {epoch + 1}, MAE Loss: {nn.L1Loss()(y_pred.reshape(-1), y_train.float().to(device)).item():.4f}")
    
        print(f"early_stop_counter: {early_stop_counter}")
    # Check for early stopping
    if best_loss is None:
        best_loss = loss.item()
    elif loss.item() < best_loss:
        best_loss = loss.item()
        early_stop_counter = 0
    else:
        early_stop_counter += 1
    if early_stop_counter >= patience:
        print("Early stopping")
        break

with torch.no_grad():
    model.eval()
    y_pred_test = pred_model(x_test.float().to(device))

# Print test loss
print(f'Test MSE loss: {criterion(y_pred_test.reshape(-1), y_test.float().to(device)).item()}')
print(f'Test MAE loss: {nn.L1Loss()(y_pred_test.reshape(-1), y_test.float().to(device)).item()}')


fig, ax = plt.subplots(1, 2, figsize=(10, 3))

m = Basemap(projection='cyl', resolution='c', ax=ax[0])
m.drawcoastlines()
ax[0].scatter(coords_test[:,1], coords_test[:,0], c=y_test, s=5)
ax[0].set_title('True')

m = Basemap(projection='cyl', resolution='c', ax=ax[1])
m.drawcoastlines()
ax[1].scatter(coords_test[:,1].cpu().numpy(), coords_test[:,0].cpu().numpy(), c=y_pred_test.reshape(-1).cpu().numpy(), s=5)
ax[1].set_title('Predicted')
# plt.savefig('precipitation_predicted_day_geoclip.jpg')
# Out:
# Epoch 250, MSE Loss: 0.2115
# Epoch 250, MAE Loss: 0.3256
# early_stop_counter: 0
# Epoch 500, MSE Loss: 0.0953
# Epoch 500, MAE Loss: 0.2219
# early_stop_counter: 2
# Epoch 750, MSE Loss: 0.0672
# Epoch 750, MAE Loss: 0.1908
# early_stop_counter: 11
# Epoch 1000, MSE Loss: 0.0546
# Epoch 1000, MAE Loss: 0.1721
# early_stop_counter: 4
# Epoch 1250, MSE Loss: 0.0461
# Epoch 1250, MAE Loss: 0.1603
# early_stop_counter: 0
# Epoch 1500, MSE Loss: 0.0412
# Epoch 1500, MAE Loss: 0.1525
# early_stop_counter: 4
# Epoch 1750, MSE Loss: 0.0370
# Epoch 1750, MAE Loss: 0.1451
# early_stop_counter: 17
# Epoch 2000, MSE Loss: 0.0337
# Epoch 2000, MAE Loss: 0.1381
# early_stop_counter: 3
# Epoch 2250, MSE Loss: 0.0319
# Epoch 2250, MAE Loss: 0.1343
# early_stop_counter: 10
# Epoch 2500, MSE Loss: 0.0288
# Epoch 2500, MAE Loss: 0.1286
# early_stop_counter: 0
# Epoch 2750, MSE Loss: 0.0290
# Epoch 2750, MAE Loss: 0.1299
# early_stop_counter: 15
# Epoch 3000, MSE Loss: 0.0256
# Epoch 3000, MAE Loss: 0.1217
# early_stop_counter: 0
# Epoch 3250, MSE Loss: 0.0247
# Epoch 3250, MAE Loss: 0.1192
# early_stop_counter: 5
# Epoch 3500, MSE Loss: 0.0235
# Epoch 3500, MAE Loss: 0.1173
# early_stop_counter: 5
# Epoch 3750, MSE Loss: 0.0226
# Epoch 3750, MAE Loss: 0.1145
# early_stop_counter: 5
# Epoch 4000, MSE Loss: 0.0216
# Epoch 4000, MAE Loss: 0.1125
# early_stop_counter: 2
# Epoch 4250, MSE Loss: 0.0211
# Epoch 4250, MAE Loss: 0.1115
# early_stop_counter: 15
# Epoch 4500, MSE Loss: 0.0207
# Epoch 4500, MAE Loss: 0.1095
# early_stop_counter: 7
# Epoch 4750, MSE Loss: 0.0195
# Epoch 4750, MAE Loss: 0.1068
# early_stop_counter: 0
# Epoch 5000, MSE Loss: 0.0199
# Epoch 5000, MAE Loss: 0.1086
# early_stop_counter: 12
# Epoch 5250, MSE Loss: 0.0187
# Epoch 5250, MAE Loss: 0.1046
# early_stop_counter: 3
# Epoch 5500, MSE Loss: 0.0188
# Epoch 5500, MAE Loss: 0.1057
# early_stop_counter: 10
# Epoch 5750, MSE Loss: 0.0187
# Epoch 5750, MAE Loss: 0.1054
# early_stop_counter: 17
# Epoch 6000, MSE Loss: 0.0179
# Epoch 6000, MAE Loss: 0.1024
# early_stop_counter: 5
# Epoch 6250, MSE Loss: 0.0176
# Epoch 6250, MAE Loss: 0.1016
# early_stop_counter: 14
# Epoch 6500, MSE Loss: 0.0165
# Epoch 6500, MAE Loss: 0.0988
# early_stop_counter: 0
# Epoch 6750, MSE Loss: 0.0173
# Epoch 6750, MAE Loss: 0.1017
# early_stop_counter: 14
# Epoch 7000, MSE Loss: 0.0160
# Epoch 7000, MAE Loss: 0.0972
# early_stop_counter: 27
# Epoch 7250, MSE Loss: 0.0170
# Epoch 7250, MAE Loss: 0.1010
# early_stop_counter: 11
# Epoch 7500, MSE Loss: 0.0169
# Epoch 7500, MAE Loss: 0.1009
# early_stop_counter: 14
# Epoch 7750, MSE Loss: 0.0160
# Epoch 7750, MAE Loss: 0.0978
# early_stop_counter: 20
# Epoch 8000, MSE Loss: 0.0149
# Epoch 8000, MAE Loss: 0.0939
# early_stop_counter: 25
# Epoch 8250, MSE Loss: 0.0152
# Epoch 8250, MAE Loss: 0.0946
# early_stop_counter: 8
# Epoch 8500, MSE Loss: 0.0154
# Epoch 8500, MAE Loss: 0.0952
# early_stop_counter: 7
# Epoch 8750, MSE Loss: 0.0157
# Epoch 8750, MAE Loss: 0.0965
# early_stop_counter: 18
# Epoch 9000, MSE Loss: 0.0140
# Epoch 9000, MAE Loss: 0.0909
# early_stop_counter: 22
# Epoch 9250, MSE Loss: 0.0139
# Epoch 9250, MAE Loss: 0.0907
# early_stop_counter: 1
# Epoch 9500, MSE Loss: 0.0145
# Epoch 9500, MAE Loss: 0.0934
# early_stop_counter: 4
# Epoch 9750, MSE Loss: 0.0153
# Epoch 9750, MAE Loss: 0.0962
# early_stop_counter: 13
# Epoch 10000, MSE Loss: 0.0153
# Epoch 10000, MAE Loss: 0.0963
# early_stop_counter: 19
# Epoch 10250, MSE Loss: 0.0132
# Epoch 10250, MAE Loss: 0.0883
# early_stop_counter: 25
# Epoch 10500, MSE Loss: 0.0135
# Epoch 10500, MAE Loss: 0.0894
# early_stop_counter: 5
# Epoch 10750, MSE Loss: 0.0139
# Epoch 10750, MAE Loss: 0.0907
# early_stop_counter: 11
# Epoch 11000, MSE Loss: 0.0142
# Epoch 11000, MAE Loss: 0.0918
# early_stop_counter: 11
# Epoch 11250, MSE Loss: 0.0151
# Epoch 11250, MAE Loss: 0.0952
# early_stop_counter: 16
# Epoch 11500, MSE Loss: 0.0125
# Epoch 11500, MAE Loss: 0.0859
# early_stop_counter: 26
# Epoch 11750, MSE Loss: 0.0125
# Epoch 11750, MAE Loss: 0.0864
# early_stop_counter: 4
# Epoch 12000, MSE Loss: 0.0122
# Epoch 12000, MAE Loss: 0.0850
# early_stop_counter: 25
# Epoch 12250, MSE Loss: 0.0133
# Epoch 12250, MAE Loss: 0.0889
# early_stop_counter: 6
# Epoch 12500, MSE Loss: 0.0135
# Epoch 12500, MAE Loss: 0.0896
# early_stop_counter: 11
# Epoch 12750, MSE Loss: 0.0126
# Epoch 12750, MAE Loss: 0.0864
# early_stop_counter: 37
# Epoch 13000, MSE Loss: 0.0119
# Epoch 13000, MAE Loss: 0.0837
# early_stop_counter: 24
# Epoch 13250, MSE Loss: 0.0121
# Epoch 13250, MAE Loss: 0.0846
# early_stop_counter: 41
# Epoch 13500, MSE Loss: 0.0117
# Epoch 13500, MAE Loss: 0.0829
# early_stop_counter: 20
# Epoch 13750, MSE Loss: 0.0116
# Epoch 13750, MAE Loss: 0.0831
# early_stop_counter: 3
# Epoch 14000, MSE Loss: 0.0117
# Epoch 14000, MAE Loss: 0.0837
# early_stop_counter: 6
# Epoch 14250, MSE Loss: 0.0121
# Epoch 14250, MAE Loss: 0.0847
# early_stop_counter: 10
# Epoch 14500, MSE Loss: 0.0127
# Epoch 14500, MAE Loss: 0.0880
# early_stop_counter: 32
# Epoch 14750, MSE Loss: 0.0118
# Epoch 14750, MAE Loss: 0.0842
# early_stop_counter: 15
# Epoch 15000, MSE Loss: 0.0112
# Epoch 15000, MAE Loss: 0.0811
# early_stop_counter: 2
# Epoch 15250, MSE Loss: 0.0114
# Epoch 15250, MAE Loss: 0.0821
# early_stop_counter: 7
# Epoch 15500, MSE Loss: 0.0127
# Epoch 15500, MAE Loss: 0.0873
# early_stop_counter: 13
# Epoch 15750, MSE Loss: 0.0109
# Epoch 15750, MAE Loss: 0.0801
# early_stop_counter: 41
# Epoch 16000, MSE Loss: 0.0134
# Epoch 16000, MAE Loss: 0.0901
# early_stop_counter: 20
# Epoch 16250, MSE Loss: 0.0119
# Epoch 16250, MAE Loss: 0.0843
# early_stop_counter: 34
# Epoch 16500, MSE Loss: 0.0124
# Epoch 16500, MAE Loss: 0.0861
# early_stop_counter: 14
# Epoch 16750, MSE Loss: 0.0117
# Epoch 16750, MAE Loss: 0.0834
# early_stop_counter: 6
# Epoch 17000, MSE Loss: 0.0105
# Epoch 17000, MAE Loss: 0.0786
# early_stop_counter: 56
# Epoch 17250, MSE Loss: 0.0108
# Epoch 17250, MAE Loss: 0.0804
# early_stop_counter: 7
# Epoch 17500, MSE Loss: 0.0104
# Epoch 17500, MAE Loss: 0.0781
# early_stop_counter: 25
# Epoch 17750, MSE Loss: 0.0108
# Epoch 17750, MAE Loss: 0.0804
# early_stop_counter: 7
# Epoch 18000, MSE Loss: 0.0116
# Epoch 18000, MAE Loss: 0.0840
# early_stop_counter: 12
# Epoch 18250, MSE Loss: 0.0111
# Epoch 18250, MAE Loss: 0.0820
# early_stop_counter: 14
# Epoch 18500, MSE Loss: 0.0102
# Epoch 18500, MAE Loss: 0.0776
# early_stop_counter: 9
# Epoch 18750, MSE Loss: 0.0110
# Epoch 18750, MAE Loss: 0.0816
# early_stop_counter: 11
# Epoch 19000, MSE Loss: 0.0121
# Epoch 19000, MAE Loss: 0.0862
# early_stop_counter: 21
# Epoch 19250, MSE Loss: 0.0100
# Epoch 19250, MAE Loss: 0.0767
# early_stop_counter: 52
# Epoch 19500, MSE Loss: 0.0099
# Epoch 19500, MAE Loss: 0.0762
# early_stop_counter: 24
# Epoch 19750, MSE Loss: 0.0120
# Epoch 19750, MAE Loss: 0.0861
# early_stop_counter: 16
# Epoch 20000, MSE Loss: 0.0131
# Epoch 20000, MAE Loss: 0.0906
# early_stop_counter: 16
# Epoch 20250, MSE Loss: 0.0128
# Epoch 20250, MAE Loss: 0.0895
# early_stop_counter: 17
# Epoch 20500, MSE Loss: 0.0115
# Epoch 20500, MAE Loss: 0.0840
# early_stop_counter: 18
# Epoch 20750, MSE Loss: 0.0129
# Epoch 20750, MAE Loss: 0.0900
# early_stop_counter: 18
# Epoch 21000, MSE Loss: 0.0097
# Epoch 21000, MAE Loss: 0.0758
# early_stop_counter: 61
# Epoch 21250, MSE Loss: 0.0103
# Epoch 21250, MAE Loss: 0.0785
# early_stop_counter: 23
# Epoch 21500, MSE Loss: 0.0109
# Epoch 21500, MAE Loss: 0.0815
# early_stop_counter: 44
# Epoch 21750, MSE Loss: 0.0098
# Epoch 21750, MAE Loss: 0.0762
# early_stop_counter: 8
# Epoch 22000, MSE Loss: 0.0111
# Epoch 22000, MAE Loss: 0.0818
# early_stop_counter: 33
# Epoch 22250, MSE Loss: 0.0094
# Epoch 22250, MAE Loss: 0.0744
# early_stop_counter: 26
# Epoch 22500, MSE Loss: 0.0104
# Epoch 22500, MAE Loss: 0.0793
# early_stop_counter: 29
# Epoch 22750, MSE Loss: 0.0107
# Epoch 22750, MAE Loss: 0.0802
# early_stop_counter: 83
# Early stopping
# Test MSE loss: 0.16151700913906097
# Test MAE loss: 0.2491655796766281
# Text(0.5, 1.0, 'Predicted')

# %%
print(losses)
plt.plot(losses)
# Out:
# [1.0017081499099731, 1.0013601779937744, 1.001143217086792, 1.000891089439392, 1.0005605220794678, 1.0001559257507324, 0.9996821880340576, 0.9991321563720703, 0.9984893798828125, 0.9977361559867859, 0.9968571662902832, 0.9958397746086121, 0.9946674704551697, 0.9933229684829712, 0.9917951226234436, 0.9900904893875122, 0.988202691078186, 0.986099123954773, 0.9837582111358643, 0.9811647534370422, 0.9782993793487549, 0.9751428365707397, 0.9716721773147583, 0.9678707718849182, 0.9637207388877869, 0.9592117071151733, 0.9543440937995911, 0.9490822553634644, 0.9434126019477844, 0.9373401403427124, 0.9308770298957825, 0.9240251183509827, 0.9167935848236084, 0.9091938138008118, 0.9012365937232971, 0.8929339647293091, 0.8843140006065369, 0.875386655330658, 0.8661574721336365, 0.8566540479660034, 0.8469197750091553, 0.836999237537384, 0.826981782913208, 0.8169764876365662, 0.8070552349090576, 0.7972730398178101, 0.7877243757247925, 0.7785338759422302, 0.7698063254356384, 0.7616268396377563, 0.7540673613548279, 0.7471839785575867, 0.7409874796867371, 0.7354393601417542, 0.7304564118385315, 0.7259157299995422, 0.7216875553131104, 0.717627763748169, 0.7136265635490417, 0.7096154093742371, 0.7055850028991699, 0.7015729546546936, 0.6976522207260132, 0.6939153671264648, 0.6904506683349609, 0.6873220205307007, 0.6845371723175049, 0.6820594668388367, 0.679812490940094, 0.6777147650718689, 0.6756982207298279, 0.6737054586410522, 0.6717010140419006, 0.6696701049804688, 0.6676055192947388, 0.6655184030532837, 0.6634357571601868, 0.6613889932632446, 0.659389317035675, 0.6574387550354004, 0.6555342674255371, 0.6536706686019897, 0.6518462896347046, 0.6500469446182251, 0.6482537388801575, 0.6464568972587585, 0.6446597576141357, 0.6428675055503845, 0.6410835385322571, 0.6393100023269653, 0.6375412940979004, 0.6357700824737549, 0.6339885592460632, 0.6321921348571777, 0.6303741335868835, 0.6285424828529358, 0.6267013549804688, 0.624859631061554, 0.6230096220970154, 0.6211503744125366, 0.619269073009491, 0.6173694133758545, 0.615455687046051, 0.6135303378105164, 0.6116031408309937, 0.6096878051757812, 0.6077787280082703, 0.6058850884437561, 0.6039941310882568, 0.6020629405975342, 0.6000735759735107, 0.5980431437492371, 0.5960185527801514, 0.5940154194831848, 0.5920082330703735, 0.5899757742881775, 0.5879009962081909, 0.5858024954795837, 0.5837008357048035, 0.5816042423248291, 0.5795086622238159, 0.5773992538452148, 0.575268030166626, 0.5731117129325867, 0.5709309577941895, 0.5687291026115417, 0.566514253616333, 0.5642929673194885, 0.5620772838592529, 0.5598614811897278, 0.5576438903808594, 0.5554220676422119, 0.5531976819038391, 0.5510022640228271, 0.5488958358764648, 0.5469540357589722, 0.5450717210769653, 0.5426993370056152, 0.5400615930557251, 0.538025438785553, 0.5362725853919983, 0.5339824557304382, 0.5315629839897156, 0.5296769142150879, 0.5277371406555176, 0.5253852009773254, 0.5232688784599304, 0.5214401483535767, 0.5193461775779724, 0.5171325206756592, 0.515184760093689, 0.5133007764816284, 0.5112176537513733, 0.5091143250465393, 0.5071991086006165, 0.5053082704544067, 0.5032809376716614, 0.5012368559837341, 0.4993138909339905, 0.49744468927383423, 0.4955195188522339, 0.49352961778640747, 0.4915745258331299, 0.48969566822052, 0.48786500096321106, 0.48604169487953186, 0.48419636487960815, 0.48234036564826965, 0.4804980158805847, 0.47869327664375305, 0.4769236445426941, 0.4751816689968109, 0.47347739338874817, 0.471809983253479, 0.4702076315879822, 0.46871495246887207, 0.46741798520088196, 0.46623948216438293, 0.46486225724220276, 0.4627736210823059, 0.4607653319835663, 0.4595540463924408, 0.4586065709590912, 0.45710432529449463, 0.4552297592163086, 0.45391079783439636, 0.4529484212398529, 0.45155635476112366, 0.44989219307899475, 0.4485796391963959, 0.447556734085083, 0.44630739092826843, 0.4447980523109436, 0.44348108768463135, 0.44242215156555176, 0.44129225611686707, 0.4399626851081848, 0.43862035870552063, 0.4374564588069916, 0.43639886379241943 ...

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# 设置全局字体
plt.rcParams['font.family'] = 'Times New Roman'

fig, ax = plt.subplots(1, 2, figsize=(18, 5))
y_test = y_test * y_std + y_mean
y_pred_test = y_pred_test * y_std + y_mean
m = Basemap(projection='cyl', resolution='c', ax=ax[0])
m.drawcoastlines()
m.drawmeridians(np.arange(-180, 180, 30), labels=[0,0,0,1])  # 绘制经线
m.drawparallels(np.arange(-90, 90, 30), labels=[1,0,0,0])  # 绘制纬线
scatter_true = ax[0].scatter(coords_test[:,1], coords_test[:,0], c=y_test, s=20,
                             cmap='coolwarm')
ax[0].set_title('True', fontsize=14)

# 添加颜色条
cbar_true = plt.colorbar(scatter_true, ax=ax[0], shrink=0.7)
# cbar_true.set_label('True Values', fontsize=12)

m = Basemap(projection='cyl', resolution='c', ax=ax[1])
m.drawcoastlines()
m.drawmeridians(np.arange(-180, 180, 30), labels=[0,0,0,1])  # 绘制经线
m.drawparallels(np.arange(-90, 90, 30), labels=[1,0,0,0])  # 绘制纬线
scatter_pred = ax[1].scatter(coords_test[:,1].cpu().numpy(), coords_test[:,0].cpu().numpy(), c=y_pred_test.reshape(-1).cpu().numpy(), 
                             s=20,
                             cmap='coolwarm')
ax[1].set_title('Predicted', fontsize=14)

# 添加颜色条
cbar_pred = plt.colorbar(scatter_pred, ax=ax[1], shrink=0.7)
# cbar_pred.set_label('Predicted Values', fontsize=12)
# 调整子图之间的距离
plt.subplots_adjust(wspace=0.02)
# plt.tight_layout()
plt.savefig('geoclip_precipitation_predicted_day.pdf', dpi=1000,
            bbox_inches='tight'
            )
